# %% [markdown]
# # 01 - Data Profile and Validation
#
# This notebook profiles the training data and runs the project validation checks.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import pandas as pd
from risk_case.data.validation import validate_dataset

# %%
train_path = ROOT / 'final_dataset' / 'final_dataset' / 'train.csv'
df = pd.read_csv(train_path, low_memory=False)
df.shape

# %%
result = validate_dataset(df)
print('ok:', result.ok)
print('errors:', result.errors)
print('warnings:', result.warnings)

# %%
df[['premium', 'premium_wo_term', 'claim_amount', 'is_claim']].describe(include='all')
