# %% [markdown]
# # 02 - Baseline Model and Pricing
#
# This notebook runs the end-to-end experiment and inspects pricing KPIs.

# %%
from pathlib import Path
import json
import sys

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from risk_case.orchestration.run_pipeline import run_experiment

# %%
config_path = ROOT / 'configs' / 'default.json'
result = run_experiment(config_path)
result['run_id']

# %%
run_dir = Path(result['run_dir'])
metrics = json.loads((run_dir / 'metrics.json').read_text(encoding='utf-8'))
metrics

# %%
import pandas as pd

pred = pd.read_csv(run_dir / 'valid_predictions.csv')
pred[['premium', 'new_premium', 'price_delta_pct', 'p_claim', 'expected_loss']].head(10)
