# %% [markdown]
# # 03 - Full ML-ready EDA (Policy + Driver)
#
# Полноценный EDA для риск-кейса: quality checks, target diagnostics, policy-vs-driver, leakage screening и model-readiness выводы.

# %%
from pathlib import Path
import sys
import json

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import pandas as pd
from risk_case.eda import EDAConfig, run_eda

# %% [markdown]
# ## 1. Run EDA pipeline

# %%
cfg = EDAConfig.from_json(ROOT / 'configs' / 'eda.json')
result = run_eda(cfg, ROOT)
result

# %% [markdown]
# ## 2. Dataset overview and schema gap

# %%
profile = json.loads((ROOT / 'artifacts' / 'eda' / 'metadata' / 'eda_profile.json').read_text(encoding='utf-8'))
profile

# %%
schema_diff = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'schema_diff.csv')
schema_diff

# %% [markdown]
# ## 3. Missingness analysis

# %%
missing_top20 = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'missing_top20.csv')
missing_top20.head(20)

# %%
from IPython.display import Image
Image(filename=str(ROOT / 'artifacts' / 'eda' / 'figures' / 'missing_top20.png'))

# %% [markdown]
# ## 4. Target imbalance and claim severity

# %%
Image(filename=str(ROOT / 'artifacts' / 'eda' / 'figures' / 'target_distribution.png'))

# %%
Image(filename=str(ROOT / 'artifacts' / 'eda' / 'figures' / 'claim_amount_log_hist.png'))

# %% [markdown]
# ## 5. Policy vs Driver hierarchy

# %%
policy_vs_driver = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'policy_vs_driver_kpis.csv')
policy_vs_driver

# %%
Image(filename=str(ROOT / 'artifacts' / 'eda' / 'figures' / 'rows_per_contract.png'))

# %% [markdown]
# ## 6. Leakage screening

# %%
watchlist = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'leakage_watchlist_numeric_corr.csv')
watchlist.head(20)

# %%
blacklist = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'leakage_blacklist_columns.csv')
blacklist

# %% [markdown]
# ## 7. Categorical and numeric diagnostics

# %%
cat_card = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'categorical_cardinality.csv')
cat_card.head(20)

# %%
numeric_summary = pd.read_csv(ROOT / 'artifacts' / 'eda' / 'tables' / 'numeric_summary.csv')
numeric_summary.head(20)

# %% [markdown]
# ## 8. Final conclusions and action plan

# %%
summary_md = (ROOT / 'reports' / 'eda_summary.md').read_text(encoding='utf-8')
print(summary_md)
